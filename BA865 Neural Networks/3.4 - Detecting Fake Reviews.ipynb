# %% [markdown]
# #**Detecting Fake Reviews**

# %% [markdown]
# This dataset is the product of research by a few folks in Computer Science: https://aclanthology.org/N13-1053.pdf. There is even a consumer-facing tool based on the model, here: http://reviewskeptic.com/.

# %%
import tensorflow as tf
from tensorflow import keras
from google.colab import files
import pandas as pd
import io

trip_advisor = pd.read_csv('https://raw.githubusercontent.com/gburtch/BA865-2022/main/Week%203/datasets/deceptive-opinion.csv')

#uploaded = files.upload()
#trip_advisor = pd.read_csv(io.BytesIO(uploaded['deceptive-opinion.csv']))
trip_advisor.describe(include='all')
# Out:
#        deceptive  ...                                               text
# count       1600  ...                                               1600
# unique         2  ...                                               1596
# top     truthful  ...  The Omni was chosen for it's location whichwor...
# freq         800  ...                                                  2
#
# [4 rows x 5 columns]

# %%
trip_advisor['deceptive'].head(10)

# %%
trip_advisor.head(10)
# Out:
#   deceptive  ...                                               text
# 0  truthful  ...  We stayed for a one night getaway with family ...
# 1  truthful  ...  Triple A rate with upgrade to view room was le...
# 2  truthful  ...  This comes a little late as I'm finally catchi...
# 3  truthful  ...  The Omni Chicago really delivers on all fronts...
# 4  truthful  ...  I asked for a high floor away from the elevato...
# 5  truthful  ...  I stayed at the Omni for one night following a...
# 6  truthful  ...  We stayed in the Conrad for 4 nights just befo...
# 7  truthful  ...  Just got back from 2 days up in Chicago shoppi...
# 8  truthful  ...  We arrived at the Omni on 2nd September for a ...
# 9  truthful  ...  On our visit to Chicago, we chose the Hyatt du...
#
# [10 rows x 5 columns]

# %% [markdown]
# We can use some of the Keras utilities to pre-process the text.
#
# *Q: What features should we use for our prediction?*

# %%
import numpy as np
from keras.preprocessing.text import text_to_word_sequence

# The dataset is perfectly balanced, so 50% accuracy will be equivalent to a random guess. 
labels = np.where(trip_advisor['deceptive']=='truthful',0,1)

text = []
for i in range(len(trip_advisor)):
  text.append(text_to_word_sequence(trip_advisor['text'][i])) # This strips punctuation, odd characters, and makes things lower-case.

# %%
text

# %% [markdown]
# This is another pre-processing step, but it's optional.
#
# *Q: What does this code block do?*

# %%
min_freq = 1
##首先account the comment in review
word_freq = {}
for review in text:
  for term in review:
    try:
        word_freq[term] = word_freq[term]+1
    except KeyError:
        word_freq[term] = 1

max_freq = max(i for i in word_freq.values())
for i in range(len(text)):
  text[i] = [term for term in text[i] if word_freq[term] >= min_freq & word_freq[term] <= max_freq]

# %% [markdown]
# Here, we are making our integer codings for the text tokens.

# %%
# We declare a set, which we populate from terms from the corpus, one by one. 
# Sets only allow 'unique' values. 
unique_terms = {term for review in text for term in review}
print(f'We have {len(unique_terms)} unique tokens in our dataset.')

# We can then easily make a term-integer dictionary and an integer-term dictionary (for reverse lookup)
word_index = {term: number for number, term in enumerate(unique_terms)}
reverse_index = {number: term for number, term in enumerate(unique_terms)}
# Out:
# We have 10275 unique tokens in our dataset.

# %% [markdown]
# One-hot encoding the text can be done very explicitly now, as a nested loop.

# %%
def vectorize_sequences(sequences, dimension=len(unique_terms)): 
    # Make our blank matrix of 0's to store hot encodings.
    results = np.zeros((len(sequences), dimension))

    # For each observation and element in that observation,
    # Update the blank matrix to a 1 at row obs, column element value.
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, word_index[j]] = 1.
    return results

text_onehot = vectorize_sequences(text)

text_onehot.shape
# Out:
# (1600, 10275)

# %% [markdown]
# Don't forget we have a few other features in the data. It's not just about the review text...

# %%
# One hot encoding the hotels. 
hotel_dict = {hotel : index for index, hotel in enumerate(set(trip_advisor['hotel']))}
hotels = []
for hotel in trip_advisor['hotel']:
  hotels.append(hotel_dict[hotel])

hotels_onehot = keras.utils.to_categorical(np.array(hotels))

# One hot encoding the review source
source_int = np.where(np.array(trip_advisor['source'])=='MTurk',0,np.where(np.array(trip_advisor['source'])=='TripAdvisor',1,2))
source_onehot = keras.utils.to_categorical(source_int)

# Binarizing the polarity
polarity_bin = np.where(np.array(trip_advisor['polarity'])=="negative",0,1).reshape(1600,1)

# Last step, we shuffle the data
data_onehot = np.concatenate((labels.reshape(1600,1),text_onehot,hotels_onehot,polarity_bin),axis=1)
np.random.shuffle(data_onehot)
#####如果不shuffle的话，可能排序有问题，可能有意为之，所以要在做之前shuffle一下 ， randomize.

# Then we pull out predictors and labels.
predictors = data_onehot[:,1:]
labels = data_onehot[:,0]

# %% [markdown]
# Now we can fit out model to the resulting data. Once again we have k-fold cross validation here. This model is incapable of learning anything much (validation accuracy never really surpasses 55-56%, and the loss is always increasing in training).

# %%
from tensorflow.keras import layers
import matplotlib.pyplot as plt

def build_model():
    model = keras.Sequential([
        # This is essentially a dense layer that mimics word embedding; we are reducing the one-hot encoded text (10,000+ one-hot tokens) down to 750 latent dimensions.
        layers.Dense(750, activation="linear"),
        layers.Dense(50, activation="relu",kernel_regularizer="l2"),
        layers.Dense(5, activation="relu"),
        layers.Dense(1, activation="sigmoid")
    ])
    model.compile(optimizer=keras.optimizers.Adadelta(learning_rate=0.01), loss="binary_crossentropy", metrics=[keras.metrics.BinaryAccuracy(threshold=0.5)])
    return model

model = build_model()

data_train = predictors[:1200]
labels_train = labels[:1200]
data_test = predictors[1200:]
labels_test = labels[1200:]

k = 4
num_validation_samples = len(data_train) // k
num_epochs = 50
batch_sizes = 25
all_loss_histories = []
all_val_loss_histories = []  
all_acc_histories = []
all_val_acc_histories = []

# For each validation fold, we will train a full set of epochs, and store the history. 
for fold in range(k):
    validation_data = data_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    validation_targets = labels_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    training_data = np.concatenate([
        data_train[:num_validation_samples * fold],
        data_train[num_validation_samples * (fold + 1):]])
    training_targets = np.concatenate([
        labels_train[:num_validation_samples * fold],
        labels_train[num_validation_samples * (fold + 1):]])
    model = build_model()
    history = model.fit(training_data, training_targets, 
                        validation_data = (validation_data,validation_targets), 
                        epochs=num_epochs, batch_size=batch_sizes)
    val_loss_history = history.history['val_loss']
    val_acc_history = history.history['val_binary_accuracy']
    loss_history = history.history['loss']
    acc_history = history.history['binary_accuracy']
    all_val_loss_histories.append(val_loss_history)
    all_loss_histories.append(loss_history)
    all_val_acc_histories.append(val_acc_history)
    all_acc_histories.append(acc_history)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 2s 12ms/step - loss: 1.6336 - binary_accuracy: 0.5144 - val_loss: 1.6272 - val_binary_accuracy: 0.5267
# Epoch 2/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.6173 - binary_accuracy: 0.5522 - val_loss: 1.6202 - val_binary_accuracy: 0.5200
# Epoch 3/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.6031 - binary_accuracy: 0.5744 - val_loss: 1.6134 - val_binary_accuracy: 0.5133
# Epoch 4/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5888 - binary_accuracy: 0.6078 - val_loss: 1.6071 - val_binary_accuracy: 0.5100
# Epoch 5/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5746 - binary_accuracy: 0.6378 - val_loss: 1.6011 - val_binary_accuracy: 0.5100
# Epoch 6/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5605 - binary_accuracy: 0.6533 - val_loss: 1.5942 - val_binary_accuracy: 0.5067
# Epoch 7/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5463 - binary_accuracy: 0.7000 - val_loss: 1.5888 - val_binary_accuracy: 0.5333
# Epoch 8/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5323 - binary_accuracy: 0.7011 - val_loss: 1.5818 - val_binary_accuracy: 0.5200
# Epoch 9/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5184 - binary_accuracy: 0.7333 - val_loss: 1.5763 - val_binary_accuracy: 0.5233
# Epoch 10/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5041 - binary_accuracy: 0.7478 - val_loss: 1.5709 - val_binary_accuracy: 0.5167
# Epoch 11/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4902 - binary_accuracy: 0.7622 - val_loss: 1.5641 - val_binary_accuracy: 0.5333
# Epoch 12/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4761 - binary_accuracy: 0.7822 - val_loss: 1.5584 - val_binary_accuracy: 0.5300
# Epoch 13/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4620 - binary_accuracy: 0.7878 - val_loss: 1.5518 - val_binary_accuracy: 0.5433
# Epoch 14/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4483 - binary_accuracy: 0.7967 - val_loss: 1.5457 - val_binary_accuracy: 0.5333
# Epoch 15/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4346 - binary_accuracy: 0.8189 - val_loss: 1.5401 - val_binary_accuracy: 0.5367
# Epoch 16/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4209 - binary_accuracy: 0.8356 - val_loss: 1.5347 - val_binary_accuracy: 0.5433
# Epoch 17/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4073 - binary_accuracy: 0.8344 - val_loss: 1.5296 - val_binary_accuracy: 0.5500
# Epoch 18/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3933 - binary_accuracy: 0.8467 - val_loss: 1.5242 - val_binary_accuracy: 0.5567
# Epoch 19/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3804 - binary_accuracy: 0.8467 - val_loss: 1.5191 - val_binary_accuracy: 0.5567
# Epoch 20/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3669 - binary_accuracy: 0.8633 - val_loss: 1.5145 - val_binary_accuracy: 0.5500
# Epoch 21/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3535 - binary_accuracy: 0.8700 - val_loss: 1.5085 - val_binary_accuracy: 0.5400
# Epoch 22/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3399 - binary_accuracy: 0.8689 - val_loss: 1.5054 - val_binary_accuracy: 0.5567
# Epoch 23/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3270 - binary_accuracy: 0.8767 - val_loss: 1.5006 - val_binary_accuracy: 0.5500
# Epoch 24/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3135 - binary_accuracy: 0.8822 - val_loss: 1.4955 - val_binary_accuracy: 0.5500
# Epoch 25/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3008 - binary_accuracy: 0.8878 - val_loss: 1.4909 - val_binary_accuracy: 0.5500
# Epoch 26/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2879 - binary_accuracy: 0.8900 - val_loss: 1.4869 - val_binary_accuracy: 0.5500
# Epoch 27/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2750 - binary_accuracy: 0.8967 - val_loss: 1.4830 - val_binary_accuracy: 0.5533
# Epoch 28/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2625 - binary_accuracy: 0.8978 - val_loss: 1.4780 - val_binary_accuracy: 0.5500
# Epoch 29/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2499 - binary_accuracy: 0.9033 - val_loss: 1.4735 - val_binary_accuracy: 0.5500
# Epoch 30/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2374 - binary_accuracy: 0.9011 - val_loss: 1.4703 - val_binary_accuracy: 0.5533
# Epoch 31/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2250 - binary_accuracy: 0.9022 - val_loss: 1.4655 - val_binary_accuracy: 0.5400
# Epoch 32/50
# 36/36 [==============================] - 0s 5ms/step - loss: 1.2124 - binary_accuracy: 0.9044 - val_loss: 1.4615 - val_binary_accuracy: 0.5400
# Epoch 33/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2000 - binary_accuracy: 0.9067 - val_loss: 1.4583 - val_binary_accuracy: 0.5467
# Epoch 34/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1879 - binary_accuracy: 0.9089 - val_loss: 1.4567 - val_binary_accuracy: 0.5467
# Epoch 35/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1758 - binary_accuracy: 0.9133 - val_loss: 1.4513 - val_binary_accuracy: 0.5367
# Epoch 36/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1639 - binary_accuracy: 0.9133 - val_loss: 1.4489 - val_binary_accuracy: 0.5400
# Epoch 37/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1519 - binary_accuracy: 0.9133 - val_loss: 1.4468 - val_binary_accuracy: 0.5467
# Epoch 38/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1404 - binary_accuracy: 0.9167 - val_loss: 1.4422 - val_binary_accuracy: 0.5300
# Epoch 39/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1282 - binary_accuracy: 0.9211 - val_loss: 1.4404 - val_binary_accuracy: 0.5400
# Epoch 40/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1164 - binary_accuracy: 0.9211 - val_loss: 1.4363 - val_binary_accuracy: 0.5367
# Epoch 41/50
# 36/36 [==============================] - 0s 5ms/step - loss: 1.1052 - binary_accuracy: 0.9256 - val_loss: 1.4346 - val_binary_accuracy: 0.5400
# Epoch 42/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0941 - binary_accuracy: 0.9244 - val_loss: 1.4322 - val_binary_accuracy: 0.5367
# Epoch 43/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0825 - binary_accuracy: 0.9267 - val_loss: 1.4300 - val_binary_accuracy: 0.5300
# Epoch 44/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0714 - binary_accuracy: 0.9244 - val_loss: 1.4293 - val_binary_accuracy: 0.5333
# Epoch 45/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0604 - binary_accuracy: 0.9267 - val_loss: 1.4256 - val_binary_accuracy: 0.5333
# Epoch 46/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0494 - binary_accuracy: 0.9278 - val_loss: 1.4239 - val_binary_accuracy: 0.5300
# Epoch 47/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0385 - binary_accuracy: 0.9322 - val_loss: 1.4211 - val_binary_accuracy: 0.5433
# Epoch 48/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0277 - binary_accuracy: 0.9322 - val_loss: 1.4206 - val_binary_accuracy: 0.5400
# Epoch 49/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0172 - binary_accuracy: 0.9367 - val_loss: 1.4189 - val_binary_accuracy: 0.5400
# Epoch 50/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0066 - binary_accuracy: 0.9378 - val_loss: 1.4171 - val_binary_accuracy: 0.5400
# Epoch 1/50
# 36/36 [==============================] - 1s 10ms/step - loss: 1.6272 - binary_accuracy: 0.5122 - val_loss: 1.6267 - val_binary_accuracy: 0.4867
# Epoch 2/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.6130 - binary_accuracy: 0.5444 - val_loss: 1.6195 - val_binary_accuracy: 0.4900
# Epoch 3/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5995 - binary_accuracy: 0.5711 - val_loss: 1.6124 - val_binary_accuracy: 0.5067
# Epoch 4/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5863 - binary_accuracy: 0.6022 - val_loss: 1.6052 - val_binary_accuracy: 0.5000
# Epoch 5/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5731 - binary_accuracy: 0.6467 - val_loss: 1.5979 - val_binary_accuracy: 0.5100
# Epoch 6/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5601 - binary_accuracy: 0.6622 - val_loss: 1.5908 - val_binary_accuracy: 0.4933
# Epoch 7/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5473 - binary_accuracy: 0.6989 - val_loss: 1.5837 - val_binary_accuracy: 0.4933
# Epoch 8/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5343 - binary_accuracy: 0.7078 - val_loss: 1.5768 - val_binary_accuracy: 0.4933
# Epoch 9/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5215 - binary_accuracy: 0.7500 - val_loss: 1.5696 - val_binary_accuracy: 0.4967
# Epoch 10/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5090 - binary_accuracy: 0.7478 - val_loss: 1.5626 - val_binary_accuracy: 0.5000
# Epoch 11/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4964 - binary_accuracy: 0.7711 - val_loss: 1.5557 - val_binary_accuracy: 0.5067
# Epoch 12/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4839 - binary_accuracy: 0.7900 - val_loss: 1.5490 - val_binary_accuracy: 0.4900
# Epoch 13/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4716 - binary_accuracy: 0.8056 - val_loss: 1.5425 - val_binary_accuracy: 0.4933
# Epoch 14/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4594 - binary_accuracy: 0.8133 - val_loss: 1.5358 - val_binary_accuracy: 0.4867
# Epoch 15/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4473 - binary_accuracy: 0.8211 - val_loss: 1.5294 - val_binary_accuracy: 0.4833
# Epoch 16/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4351 - binary_accuracy: 0.8344 - val_loss: 1.5232 - val_binary_accuracy: 0.4767
# Epoch 17/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4232 - binary_accuracy: 0.8411 - val_loss: 1.5169 - val_binary_accuracy: 0.4833
# Epoch 18/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4112 - binary_accuracy: 0.8489 - val_loss: 1.5108 - val_binary_accuracy: 0.4800
# Epoch 19/50
# 36/36 [==============================] - 0s 5ms/step - loss: 1.3994 - binary_accuracy: 0.8467 - val_loss: 1.5045 - val_binary_accuracy: 0.4733
# Epoch 20/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3877 - binary_accuracy: 0.8667 - val_loss: 1.4992 - val_binary_accuracy: 0.4633
# Epoch 21/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3760 - binary_accuracy: 0.8700 - val_loss: 1.4932 - val_binary_accuracy: 0.4600
# Epoch 22/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3645 - binary_accuracy: 0.8678 - val_loss: 1.4873 - val_binary_accuracy: 0.4533
# Epoch 23/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3528 - binary_accuracy: 0.8778 - val_loss: 1.4816 - val_binary_accuracy: 0.4633
# Epoch 24/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3413 - binary_accuracy: 0.8800 - val_loss: 1.4757 - val_binary_accuracy: 0.4633
# Epoch 25/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3299 - binary_accuracy: 0.8944 - val_loss: 1.4710 - val_binary_accuracy: 0.4567
# Epoch 26/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3184 - binary_accuracy: 0.8833 - val_loss: 1.4647 - val_binary_accuracy: 0.4633
# Epoch 27/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3072 - binary_accuracy: 0.8933 - val_loss: 1.4597 - val_binary_accuracy: 0.4633
# Epoch 28/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2959 - binary_accuracy: 0.8989 - val_loss: 1.4546 - val_binary_accuracy: 0.4667
# Epoch 29/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2846 - binary_accuracy: 0.9067 - val_loss: 1.4500 - val_binary_accuracy: 0.4567
# Epoch 30/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2736 - binary_accuracy: 0.9156 - val_loss: 1.4448 - val_binary_accuracy: 0.4600
# Epoch 31/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2625 - binary_accuracy: 0.9189 - val_loss: 1.4401 - val_binary_accuracy: 0.4567
# Epoch 32/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2512 - binary_accuracy: 0.9200 - val_loss: 1.4361 - val_binary_accuracy: 0.4600
# Epoch 33/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2407 - binary_accuracy: 0.9133 - val_loss: 1.4307 - val_binary_accuracy: 0.4600
# Epoch 34/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2297 - binary_accuracy: 0.9200 - val_loss: 1.4266 - val_binary_accuracy: 0.4633
# Epoch 35/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2182 - binary_accuracy: 0.9178 - val_loss: 1.4218 - val_binary_accuracy: 0.4600
# Epoch 36/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2080 - binary_accuracy: 0.9233 - val_loss: 1.4177 - val_binary_accuracy: 0.4667
# Epoch 37/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1969 - binary_accuracy: 0.9233 - val_loss: 1.4134 - val_binary_accuracy: 0.4600
# Epoch 38/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1862 - binary_accuracy: 0.9256 - val_loss: 1.4102 - val_binary_accuracy: 0.4733
# Epoch 39/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1759 - binary_accuracy: 0.9244 - val_loss: 1.4053 - val_binary_accuracy: 0.4700
# Epoch 40/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1650 - binary_accuracy: 0.9267 - val_loss: 1.4015 - val_binary_accuracy: 0.4667
# Epoch 41/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1546 - binary_accuracy: 0.9278 - val_loss: 1.3975 - val_binary_accuracy: 0.4567
# Epoch 42/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1439 - binary_accuracy: 0.9289 - val_loss: 1.3944 - val_binary_accuracy: 0.4600
# Epoch 43/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1335 - binary_accuracy: 0.9300 - val_loss: 1.3915 - val_binary_accuracy: 0.4700
# Epoch 44/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1228 - binary_accuracy: 0.9267 - val_loss: 1.3869 - val_binary_accuracy: 0.4700
# Epoch 45/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1125 - binary_accuracy: 0.9322 - val_loss: 1.3845 - val_binary_accuracy: 0.4567
# Epoch 46/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1022 - binary_accuracy: 0.9300 - val_loss: 1.3816 - val_binary_accuracy: 0.4633
# Epoch 47/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0917 - binary_accuracy: 0.9311 - val_loss: 1.3773 - val_binary_accuracy: 0.4733
# Epoch 48/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0816 - binary_accuracy: 0.9333 - val_loss: 1.3746 - val_binary_accuracy: 0.4700
# Epoch 49/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0711 - binary_accuracy: 0.9322 - val_loss: 1.3713 - val_binary_accuracy: 0.4800
# Epoch 50/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0613 - binary_accuracy: 0.9344 - val_loss: 1.3696 - val_binary_accuracy: 0.4700
# Epoch 1/50
# 36/36 [==============================] - 1s 10ms/step - loss: 1.6301 - binary_accuracy: 0.5033 - val_loss: 1.6264 - val_binary_accuracy: 0.5233
# Epoch 2/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.6173 - binary_accuracy: 0.5022 - val_loss: 1.6187 - val_binary_accuracy: 0.5233
# Epoch 3/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.6055 - binary_accuracy: 0.5067 - val_loss: 1.6112 - val_binary_accuracy: 0.5167
# Epoch 4/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5941 - binary_accuracy: 0.5022 - val_loss: 1.6036 - val_binary_accuracy: 0.5167
# Epoch 5/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5827 - binary_accuracy: 0.5044 - val_loss: 1.5961 - val_binary_accuracy: 0.5133
# Epoch 6/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5714 - binary_accuracy: 0.5100 - val_loss: 1.5887 - val_binary_accuracy: 0.5167
# Epoch 7/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5601 - binary_accuracy: 0.5189 - val_loss: 1.5814 - val_binary_accuracy: 0.5233
# Epoch 8/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5486 - binary_accuracy: 0.5122 - val_loss: 1.5739 - val_binary_accuracy: 0.5067
# Epoch 9/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5376 - binary_accuracy: 0.5322 - val_loss: 1.5668 - val_binary_accuracy: 0.5100
# Epoch 10/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5264 - binary_accuracy: 0.5289 - val_loss: 1.5595 - val_binary_accuracy: 0.5167
# Epoch 11/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5154 - binary_accuracy: 0.5333 - val_loss: 1.5523 - val_binary_accuracy: 0.5167
# Epoch 12/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5044 - binary_accuracy: 0.5422 - val_loss: 1.5456 - val_binary_accuracy: 0.5133
# Epoch 13/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4935 - binary_accuracy: 0.5356 - val_loss: 1.5387 - val_binary_accuracy: 0.5133
# Epoch 14/50
# 36/36 [==============================] - 0s 10ms/step - loss: 1.4824 - binary_accuracy: 0.5478 - val_loss: 1.5321 - val_binary_accuracy: 0.5133
# Epoch 15/50
# 36/36 [==============================] - 0s 11ms/step - loss: 1.4716 - binary_accuracy: 0.5411 - val_loss: 1.5249 - val_binary_accuracy: 0.5133
# Epoch 16/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4608 - binary_accuracy: 0.5578 - val_loss: 1.5187 - val_binary_accuracy: 0.5167
# Epoch 17/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4501 - binary_accuracy: 0.5589 - val_loss: 1.5125 - val_binary_accuracy: 0.5133
# Epoch 18/50
# 36/36 [==============================] - 0s 11ms/step - loss: 1.4395 - binary_accuracy: 0.5533 - val_loss: 1.5063 - val_binary_accuracy: 0.5200
# Epoch 19/50
# 36/36 [==============================] - 0s 13ms/step - loss: 1.4288 - binary_accuracy: 0.5700 - val_loss: 1.5008 - val_binary_accuracy: 0.5167
# Epoch 20/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4184 - binary_accuracy: 0.5611 - val_loss: 1.4943 - val_binary_accuracy: 0.5200
# Epoch 21/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4080 - binary_accuracy: 0.5733 - val_loss: 1.4878 - val_binary_accuracy: 0.5200
# Epoch 22/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3977 - binary_accuracy: 0.5911 - val_loss: 1.4825 - val_binary_accuracy: 0.5200
# Epoch 23/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3877 - binary_accuracy: 0.5833 - val_loss: 1.4763 - val_binary_accuracy: 0.5200
# Epoch 24/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3777 - binary_accuracy: 0.5967 - val_loss: 1.4712 - val_binary_accuracy: 0.5133
# Epoch 25/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3678 - binary_accuracy: 0.5944 - val_loss: 1.4653 - val_binary_accuracy: 0.5200
# Epoch 26/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3580 - binary_accuracy: 0.6044 - val_loss: 1.4600 - val_binary_accuracy: 0.5200
# Epoch 27/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3483 - binary_accuracy: 0.6156 - val_loss: 1.4546 - val_binary_accuracy: 0.5200
# Epoch 28/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3385 - binary_accuracy: 0.6200 - val_loss: 1.4500 - val_binary_accuracy: 0.5167
# Epoch 29/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3293 - binary_accuracy: 0.6044 - val_loss: 1.4432 - val_binary_accuracy: 0.5267
# Epoch 30/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3198 - binary_accuracy: 0.6322 - val_loss: 1.4383 - val_binary_accuracy: 0.5267
# Epoch 31/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3104 - binary_accuracy: 0.6322 - val_loss: 1.4332 - val_binary_accuracy: 0.5300
# Epoch 32/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3012 - binary_accuracy: 0.6344 - val_loss: 1.4275 - val_binary_accuracy: 0.5333
# Epoch 33/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2920 - binary_accuracy: 0.6500 - val_loss: 1.4235 - val_binary_accuracy: 0.5300
# Epoch 34/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2829 - binary_accuracy: 0.6567 - val_loss: 1.4190 - val_binary_accuracy: 0.5300
# Epoch 35/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2740 - binary_accuracy: 0.6578 - val_loss: 1.4137 - val_binary_accuracy: 0.5333
# Epoch 36/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2652 - binary_accuracy: 0.6678 - val_loss: 1.4099 - val_binary_accuracy: 0.5267
# Epoch 37/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2564 - binary_accuracy: 0.6644 - val_loss: 1.4053 - val_binary_accuracy: 0.5267
# Epoch 38/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2475 - binary_accuracy: 0.6811 - val_loss: 1.4012 - val_binary_accuracy: 0.5233
# Epoch 39/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2389 - binary_accuracy: 0.6900 - val_loss: 1.3970 - val_binary_accuracy: 0.5233
# Epoch 40/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2304 - binary_accuracy: 0.6944 - val_loss: 1.3931 - val_binary_accuracy: 0.5267
# Epoch 41/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2221 - binary_accuracy: 0.6956 - val_loss: 1.3883 - val_binary_accuracy: 0.5233
# Epoch 42/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2135 - binary_accuracy: 0.7000 - val_loss: 1.3844 - val_binary_accuracy: 0.5233
# Epoch 43/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2054 - binary_accuracy: 0.7133 - val_loss: 1.3802 - val_binary_accuracy: 0.5267
# Epoch 44/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1971 - binary_accuracy: 0.7156 - val_loss: 1.3753 - val_binary_accuracy: 0.5233
# Epoch 45/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1889 - binary_accuracy: 0.7233 - val_loss: 1.3714 - val_binary_accuracy: 0.5233
# Epoch 46/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1809 - binary_accuracy: 0.7244 - val_loss: 1.3673 - val_binary_accuracy: 0.5200
# Epoch 47/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1730 - binary_accuracy: 0.7344 - val_loss: 1.3634 - val_binary_accuracy: 0.5267
# Epoch 48/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1650 - binary_accuracy: 0.7400 - val_loss: 1.3602 - val_binary_accuracy: 0.5267
# Epoch 49/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1571 - binary_accuracy: 0.7444 - val_loss: 1.3564 - val_binary_accuracy: 0.5300
# Epoch 50/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1492 - binary_accuracy: 0.7533 - val_loss: 1.3532 - val_binary_accuracy: 0.5300
# Epoch 1/50
# 36/36 [==============================] - 1s 9ms/step - loss: 1.6298 - binary_accuracy: 0.5156 - val_loss: 1.6317 - val_binary_accuracy: 0.5033
# Epoch 2/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.6153 - binary_accuracy: 0.5656 - val_loss: 1.6250 - val_binary_accuracy: 0.4867
# Epoch 3/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.6008 - binary_accuracy: 0.6022 - val_loss: 1.6203 - val_binary_accuracy: 0.4733
# Epoch 4/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5864 - binary_accuracy: 0.6211 - val_loss: 1.6123 - val_binary_accuracy: 0.4767
# Epoch 5/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5723 - binary_accuracy: 0.6778 - val_loss: 1.6095 - val_binary_accuracy: 0.4767
# Epoch 6/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5577 - binary_accuracy: 0.6967 - val_loss: 1.6023 - val_binary_accuracy: 0.4800
# Epoch 7/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5433 - binary_accuracy: 0.7289 - val_loss: 1.5976 - val_binary_accuracy: 0.4767
# Epoch 8/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.5286 - binary_accuracy: 0.7622 - val_loss: 1.5921 - val_binary_accuracy: 0.4800
# Epoch 9/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.5138 - binary_accuracy: 0.7744 - val_loss: 1.5860 - val_binary_accuracy: 0.4833
# Epoch 10/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4991 - binary_accuracy: 0.8089 - val_loss: 1.5794 - val_binary_accuracy: 0.4767
# Epoch 11/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4848 - binary_accuracy: 0.8256 - val_loss: 1.5739 - val_binary_accuracy: 0.4767
# Epoch 12/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4706 - binary_accuracy: 0.8444 - val_loss: 1.5698 - val_binary_accuracy: 0.4867
# Epoch 13/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4563 - binary_accuracy: 0.8544 - val_loss: 1.5647 - val_binary_accuracy: 0.4800
# Epoch 14/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.4421 - binary_accuracy: 0.8667 - val_loss: 1.5587 - val_binary_accuracy: 0.4833
# Epoch 15/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4281 - binary_accuracy: 0.8833 - val_loss: 1.5534 - val_binary_accuracy: 0.4800
# Epoch 16/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4143 - binary_accuracy: 0.8856 - val_loss: 1.5485 - val_binary_accuracy: 0.4933
# Epoch 17/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.4008 - binary_accuracy: 0.8922 - val_loss: 1.5439 - val_binary_accuracy: 0.4767
# Epoch 18/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3869 - binary_accuracy: 0.9056 - val_loss: 1.5415 - val_binary_accuracy: 0.4800
# Epoch 19/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3736 - binary_accuracy: 0.9011 - val_loss: 1.5344 - val_binary_accuracy: 0.4733
# Epoch 20/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3598 - binary_accuracy: 0.9156 - val_loss: 1.5325 - val_binary_accuracy: 0.4767
# Epoch 21/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3467 - binary_accuracy: 0.9200 - val_loss: 1.5269 - val_binary_accuracy: 0.4667
# Epoch 22/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.3331 - binary_accuracy: 0.9167 - val_loss: 1.5243 - val_binary_accuracy: 0.4833
# Epoch 23/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3201 - binary_accuracy: 0.9200 - val_loss: 1.5177 - val_binary_accuracy: 0.4733
# Epoch 24/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.3068 - binary_accuracy: 0.9289 - val_loss: 1.5147 - val_binary_accuracy: 0.4900
# Epoch 25/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2939 - binary_accuracy: 0.9289 - val_loss: 1.5095 - val_binary_accuracy: 0.4767
# Epoch 26/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2807 - binary_accuracy: 0.9344 - val_loss: 1.5055 - val_binary_accuracy: 0.4800
# Epoch 27/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2678 - binary_accuracy: 0.9378 - val_loss: 1.5032 - val_binary_accuracy: 0.5000
# Epoch 28/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2549 - binary_accuracy: 0.9344 - val_loss: 1.4987 - val_binary_accuracy: 0.5000
# Epoch 29/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2420 - binary_accuracy: 0.9400 - val_loss: 1.4936 - val_binary_accuracy: 0.4833
# Epoch 30/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2293 - binary_accuracy: 0.9400 - val_loss: 1.4921 - val_binary_accuracy: 0.4900
# Epoch 31/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.2169 - binary_accuracy: 0.9478 - val_loss: 1.4880 - val_binary_accuracy: 0.4900
# Epoch 32/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.2040 - binary_accuracy: 0.9422 - val_loss: 1.4832 - val_binary_accuracy: 0.4933
# Epoch 33/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1917 - binary_accuracy: 0.9511 - val_loss: 1.4803 - val_binary_accuracy: 0.4900
# Epoch 34/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1792 - binary_accuracy: 0.9511 - val_loss: 1.4787 - val_binary_accuracy: 0.4933
# Epoch 35/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1669 - binary_accuracy: 0.9489 - val_loss: 1.4744 - val_binary_accuracy: 0.4933
# Epoch 36/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1548 - binary_accuracy: 0.9533 - val_loss: 1.4740 - val_binary_accuracy: 0.5000
# Epoch 37/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1428 - binary_accuracy: 0.9556 - val_loss: 1.4702 - val_binary_accuracy: 0.4933
# Epoch 38/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1311 - binary_accuracy: 0.9533 - val_loss: 1.4680 - val_binary_accuracy: 0.5067
# Epoch 39/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.1189 - binary_accuracy: 0.9544 - val_loss: 1.4666 - val_binary_accuracy: 0.5033
# Epoch 40/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.1073 - binary_accuracy: 0.9556 - val_loss: 1.4619 - val_binary_accuracy: 0.4833
# Epoch 41/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0959 - binary_accuracy: 0.9556 - val_loss: 1.4632 - val_binary_accuracy: 0.5067
# Epoch 42/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0843 - binary_accuracy: 0.9578 - val_loss: 1.4597 - val_binary_accuracy: 0.4900
# Epoch 43/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0730 - binary_accuracy: 0.9578 - val_loss: 1.4600 - val_binary_accuracy: 0.4967
# Epoch 44/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0615 - binary_accuracy: 0.9611 - val_loss: 1.4594 - val_binary_accuracy: 0.5000
# Epoch 45/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0512 - binary_accuracy: 0.9611 - val_loss: 1.4555 - val_binary_accuracy: 0.4833
# Epoch 46/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0395 - binary_accuracy: 0.9633 - val_loss: 1.4549 - val_binary_accuracy: 0.4867
# Epoch 47/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0288 - binary_accuracy: 0.9611 - val_loss: 1.4503 - val_binary_accuracy: 0.4867
# Epoch 48/50
# 36/36 [==============================] - 0s 7ms/step - loss: 1.0180 - binary_accuracy: 0.9611 - val_loss: 1.4512 - val_binary_accuracy: 0.4767
# Epoch 49/50
# 36/36 [==============================] - 0s 6ms/step - loss: 1.0073 - binary_accuracy: 0.9633 - val_loss: 1.4515 - val_binary_accuracy: 0.4933
# Epoch 50/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.9968 - binary_accuracy: 0.9644 - val_loss: 1.4459 - val_binary_accuracy: 0.4867

# %% [markdown]
# *Q: What does 'x' represent in these iterators?*
#
# *Q: Can anyone explain in simple words what this code is doing?*

# %%
average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]

# %% [markdown]
# Here we plot the cross-validated performance:

# %%
# Plot validation performance. 
plt.plot(average_loss_history,c='r')
plt.plot(average_acc_history,c="r",linestyle="dashed")
plt.plot(average_val_loss_history,c='b')
plt.plot(average_val_acc_history,c='b',linestyle="dashed")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy'])
plt.show()
