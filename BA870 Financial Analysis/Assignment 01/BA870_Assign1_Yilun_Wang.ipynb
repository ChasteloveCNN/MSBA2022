# %% [markdown]
# ## BA870 - Financial Analytics
# ## Assignment 1
# ## Yilun Wang / yilun830@bu.edu

# %%
# Knit
# !jupyter nbconvert -- to html /content/BA870_Assign1_Yilun_Wang.ipynb
# Out:
# [NbConvertApp] WARNING | pattern 'to' matched no files
# [NbConvertApp] WARNING | pattern 'html' matched no files
# [NbConvertApp] Converting notebook /content/BA870_Assign1_Yilun_Wang.ipynb to html
# [NbConvertApp] Writing 357993 bytes to /content/BA870_Assign1_Yilun_Wang.html

# %% [markdown]
# ### Part 1 - Consolidated Statement of Operation for AAPL

# %%
# Install necessary Python libraries
! pip install requests
! pip install beautifulsoup4

# %%
# Use the 'requests' library to download the necessary webpage from thge SEC server. 
import requests

# This header information MUST be submitted with your URL reuqest to the SEC website.
# If this header is not included or is incorrect, then you will not be abkle to download the data (it will be rejected by the SEC server).

headers = {'Host': 'www.sec.gov', 'Connection': 'close',
         'Accept': 'application/json, text/javascript, */*; q=0.01', 'X-Requested-With': 'XMLHttpRequest',
         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         }

URL1 = 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/R2.htm'

# Get data from webpage
# include the HEADER or you might get denied

page1 = requests.get(URL1, headers=headers)

# %%
## Use 'Beautiful Soup' Library to implement an 'html/xml parser'
from bs4 import BeautifulSoup

soup1 = BeautifulSoup(page1.content, 'lxml')

# %%
# Find the tag that identify tables
Table1 = soup1.find_all('table')

# Use 'read_html' request to directly get the uncleaned table
import pandas as pd

AAPL = pd.read_html(str(Table1))[0]
AAPL
# Out:
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions  \
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions
# 0                                           Net sales
# 1                                       Cost of sales
# 2                                        Gross margin
# 3                                 Operating expenses:
# 4                            Research and development
# 5                 Selling, general and administrative
# 6                            Total operating expenses
# 7                                    Operating income
# 8                         Other income/(expense), net
# 9            Income before provision for income taxes
# 10                         Provision for income taxes
# 11                                         Net income
# 12                                Earnings per share:
# 13                       Basic (in dollars per share)
# ...

# %%
# Clean the dollar sign, comma sign and space, then convert to float
check = AAPL.columns

AAPL[check] = AAPL[check].replace({'\$':''}, regex = True)
AAPL[check] = AAPL[check].replace({'\,':''}, regex = True)
AAPL[check] = AAPL[check].replace({' ':''}, regex = True)

AAPL
# Out:
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions  \
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions
# 0                                            Netsales
# 1                                         Costofsales
# 2                                         Grossmargin
# 3                                  Operatingexpenses:
# 4                              Researchanddevelopment
# 5                     Sellinggeneralandadministrative
# 6                              Totaloperatingexpenses
# 7                                     Operatingincome
# 8                            Otherincome/(expense)net
# 9                 Incomebeforeprovisionforincometaxes
# 10                            Provisionforincometaxes
# 11                                          Netincome
# 12                                  Earningspershare:
# 13                           Basic(indollarspershare)
# ...

# %%
# Create another dataframe to transfer numbers into float - step 1
try1 = pd.DataFrame(AAPL.iloc[:,0])
try1
# Out:
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions
# 0                                           Net sales
# 1                                       Cost of sales
# 2                                        Gross margin
# 3                                 Operating expenses:
# 4                            Research and development
# 5                 Selling, general and administrative
# 6                            Total operating expenses
# 7                                    Operating income
# 8                         Other income/(expense), net
# 9            Income before provision for income taxes
# 10                         Provision for income taxes
# 11                                         Net income
# 12                                Earnings per share:
# 13                       Basic (in dollars per share)
# ...

# %%
# Create another dataframe to transfer numbers into float - step 2
try2 = AAPL.iloc[:,1:4].replace(',', '').astype(float)
try2
# Out:
#    12 Months Ended
#      Sep. 25, 2021 Sep. 26, 2020 Sep. 28, 2019
# 0        365817.00     274515.00     260174.00
# 1        212981.00     169559.00     161782.00
# 2        152836.00     104956.00      98392.00
# 3              NaN           NaN           NaN
# 4         21914.00      18752.00      16217.00
# 5         21973.00      19916.00      18245.00
# 6         43887.00      38668.00      34462.00
# 7        108949.00      66288.00      63930.00
# 8           258.00        803.00       1807.00
# 9        109207.00      67091.00      65737.00
# 10        14527.00       9680.00      10481.00
# 11        94680.00      57411.00      55256.00
# 12             NaN           NaN           NaN
# 13            5.67          3.31          2.99
# 14            5.61          3.28          2.97
# 15             NaN           NaN           NaN
# 16     16701272.00   17352119.00   18471336.00
# 17     16864919.00   17528214.00   18595651.00
# ...

# %%
AAPL_final = try1.join(try2)
AAPL_final
# Out:
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions  \
#    CONSOLIDATED STATEMENTS OF OPERATIONS - USD ($) shares in Thousands, $ in Millions
# 0                                           Net sales
# 1                                       Cost of sales
# 2                                        Gross margin
# 3                                 Operating expenses:
# 4                            Research and development
# 5                 Selling, general and administrative
# 6                            Total operating expenses
# 7                                    Operating income
# 8                         Other income/(expense), net
# 9            Income before provision for income taxes
# 10                         Provision for income taxes
# 11                                         Net income
# 12                                Earnings per share:
# 13                       Basic (in dollars per share)
# ...

# %% [markdown]
# ### Part 2 - Income Statement for MSFT

# %%
# Use the 'requests' library to download the necessary webpage from thge SEC server. 
import requests

# This header information MUST be submitted with your URL reuqest to the SEC website.
# If this header is not included or is incorrect, then you will not be abkle to download the data (it will be rejected by the SEC server).

headers = {'Host': 'www.sec.gov', 'Connection': 'close',
         'Accept': 'application/json, text/javascript, */*; q=0.01', 'X-Requested-With': 'XMLHttpRequest',
         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         }

URL2 = 'https://www.sec.gov/Archives/edgar/data/789019/000156459021039151/R2.htm'

# Get data from webpage
# include the HEADER or you might get denied

page2 = requests.get(URL2, headers=headers)

# %%
## Use 'Beautiful Soup' Library to implement an 'html/xml parser'
from bs4 import BeautifulSoup

soup2 = BeautifulSoup(page2.content, 'lxml')

# %%
# Find the tag that identify tables
Table2 = soup2.find_all('table')

# Use 'read_html' request to directly get the table

MSFT = pd.read_html(str(Table2))[0]
MSFT
# Out:
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions  \
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions
# 0                                             Revenue
# 1                                     Cost of revenue
# 2                                        Gross margin
# 3                            Research and development
# 4                                 Sales and marketing
# 5                          General and administrative
# 6                                    Operating income
# 7                                   Other income, net
# 8                          Income before income taxes
# 9                          Provision for income taxes
# 10                                         Net income
# 11                                Earnings per share:
# 12                                              Basic
# 13                                            Diluted
# 14               Weighted average shares outstanding:
# ...

# %%
# Clean the dollar sign, comma sign and space.
check = MSFT.columns

MSFT[check] = MSFT[check].replace({'\$':''}, regex = True)
MSFT[check] = MSFT[check].replace({'\,':''}, regex = True)
MSFT[check] = MSFT[check].replace({' ':''}, regex = True)

MSFT
# Out:
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions  \
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions
# 0                                             Revenue
# 1                                       Costofrevenue
# 2                                         Grossmargin
# 3                              Researchanddevelopment
# 4                                   Salesandmarketing
# 5                            Generalandadministrative
# 6                                     Operatingincome
# 7                                      Otherincomenet
# 8                             Incomebeforeincometaxes
# 9                             Provisionforincometaxes
# 10                                          Netincome
# 11                                  Earningspershare:
# 12                                              Basic
# 13                                            Diluted
# 14                  Weightedaveragesharesoutstanding:
# ...

# %%
# Create another dataframe to transfer numbers into float - step 1
attempt1 = pd.DataFrame(MSFT.iloc[:,0])
attempt1
# Out:
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions
# 0                                             Revenue
# 1                                       Costofrevenue
# 2                                         Grossmargin
# 3                              Researchanddevelopment
# 4                                   Salesandmarketing
# 5                            Generalandadministrative
# 6                                     Operatingincome
# 7                                      Otherincomenet
# 8                             Incomebeforeincometaxes
# 9                             Provisionforincometaxes
# 10                                          Netincome
# 11                                  Earningspershare:
# 12                                              Basic
# 13                                            Diluted
# 14                  Weightedaveragesharesoutstanding:
# ...

# %%
# Create another dataframe to transfer numbers into float - step 2
attempt2 = MSFT.iloc[:,1:4].replace(',', '').astype(float)
attempt2
# Out:
#    12 Months Ended
#      Jun. 30, 2021 Jun. 30, 2020 Jun. 30, 2019
# 0        168088.00     143015.00     125843.00
# 1         52232.00      46078.00      42910.00
# 2        115856.00      96937.00      82933.00
# 3         20716.00      19269.00      16876.00
# 4         20117.00      19598.00      18213.00
# 5          5107.00       5111.00       4885.00
# 6         69916.00      52959.00      42959.00
# 7          1186.00         77.00        729.00
# 8         71102.00      53036.00      43688.00
# 9          9831.00       8755.00       4448.00
# 10        61271.00      44281.00      39240.00
# 11             NaN           NaN           NaN
# 12            8.12          5.82          5.11
# 13            8.05          5.76          5.06
# 14             NaN           NaN           NaN
# 15         7547.00       7610.00       7673.00
# 16         7608.00       7683.00       7753.00
# 17             NaN           NaN           NaN
# ...

# %%
MSFT_final = attempt1.join(attempt2)
MSFT_final
# Out:
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions  \
#    INCOME STATEMENTS - USD ($) shares in Millions, $ in Millions
# 0                                             Revenue
# 1                                       Costofrevenue
# 2                                         Grossmargin
# 3                              Researchanddevelopment
# 4                                   Salesandmarketing
# 5                            Generalandadministrative
# 6                                     Operatingincome
# 7                                      Otherincomenet
# 8                             Incomebeforeincometaxes
# 9                             Provisionforincometaxes
# 10                                          Netincome
# 11                                  Earningspershare:
# 12                                              Basic
# 13                                            Diluted
# 14                  Weightedaveragesharesoutstanding:
# ...
