# %%
# Room 3. 
Member1: Eunjin Jeong
Email: ejjeong@bu.edu

Member2: Fusu Luo
fusuluo@bu.edu


Member3: Menghe Liu
mliu926@bu.edu


Member4: Yilun Wang
yilun830@bu.edu

# %%
import random 

my_random_list = random.choices(range(2,12),k=5)
my_random_list


B={'first':'Yilun','types':['dictionary','list','tuple'],'random':my_random_list}

B
# Out:
# {'first': 'Yilun',
#  'random': [9, 10, 6, 4, 10],
#  'type': ['dictionary', 'list', 'tuple']}
