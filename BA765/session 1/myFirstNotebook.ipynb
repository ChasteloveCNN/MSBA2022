# %%
2+4
# Out:
# 6

# %%
print("hello,world")
# Out:
# hello,world

# %%
# THIs is title

# %% [markdown]
# #This is title!
# This is my **First** notebook - I already python!
# Author : *Allen*
#
# * caculator
# * greeter

# %%
x=2
y=2*x
print(y)
# Out:
# 4

# %%
- pwd
# Out:
# '/content'
